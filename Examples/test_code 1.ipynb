# %%
import gifba
import cobra as cb

# %%
m1 = cb.io.load_matlab_model('AGORA2_Models/Bifidobacterium_longum_infantis_ATCC_15697.mat')
m2 = cb.io.load_matlab_model('AGORA2_Models/Eubacterium_hallii_DSM_3353.mat')
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2684253
# Academic license - for non-commercial use only - expires 2026-07-02
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e

# %%
# AGORA Format
media = {
    'EX_o2(e)': 0, #aerobic/anaerobic
    'EX_h2o(e)': -1000,
    'EX_pi(e)': -1000,
    'EX_fe2(e)': -1000,
    'EX_fe3(e)': -1000,
    'EX_zn2(e)': -1000,
    'EX_so4(e)': -1000,
    'EX_cu2(e)': -1000,
    'EX_k(e)': -1000,
    'EX_mg2(e)': -1000,
    'EX_mn2(e)': -1000,
    'EX_cd2(e)': -1000,
    'EX_cl(e)': -1000,
    'EX_ca2(e)': -1000,
    'EX_cobalt2(e)': -1000,
    'EX_glc_D(e)': -10,
    'EX_nh4(e)': -20,

    'EX_ribflv(e)': -1000,
    'EX_pnto_R(e)': -1000,
    'EX_nac(e)': -1000,
    'EX_his_L(e)': -1000,
    'EX_asn_L(e)': -1000,
    'EX_glycys(e)': -1000,

    'EX_lys_L(e)': -1000,
    'EX_ala_L(e)': -1000,
    'EX_met_L(e)': -1000,
    'EX_leu_L(e)': -1000,
    'EX_hxan(e)': -1000,    
    'EX_ser_L(e)': -1,
}

# %%
# initialize community
community_1_2 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5])
community_1_1 = gifba.gifbaObject([m1, m1], media, rel_abund=[0.5, 0.5])
community_2_2 = gifba.gifbaObject([m2, m2], media, rel_abund=[0.5, 0.5])
# run iterations
media_flux_1_2, org_flux_1_2 = community_1_2.run_gifba(iters=5, method="pfba", early_stop=True, v=True)
media_flux_1_1, org_flux_1_1 = community_1_1.run_gifba(iters=5, method="pfba", early_stop=True, v=True)
media_flux_2_2, org_flux_2_2 = community_2_2.run_gifba(iters=5, method="pfba", early_stop=True, v=True)
# Out:
# Read LP format model from file /tmp/tmptn4xm5uu.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpwscosti_.lp
# Reading time = 0.00 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmp_e8_ex_u.lp
# Reading time = 0.00 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpfbu_7r7i.lp
# Reading time = 0.00 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpz7lb9s4h.lp
# Reading time = 0.00 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmpq1uq3xz9.lp
# Reading time = 0.00 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Iteration: 0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# EX_glc_D(e) over-consumed by factor of 2.0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# New convergence method update:
# Checking Convergence...
# Iteration: 1
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: divide by zero encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Iteration: 2
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Converged at iteration 2
# Iteration: 0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# EX_glc_D(e) over-consumed by factor of 2.0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# New convergence method update:
# Checking Convergence...
# Iteration: 1
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Iteration: 2
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Converged at iteration 2
# Iteration: 0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# EX_ser_L(e) over-consumed by factor of 2.0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# EX_glc_D(e) over-consumed by factor of 2.0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# New convergence method update:
# Checking Convergence...
# Iteration: 1
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Iteration: 2
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# /home/rseag/UVM/M3_Lab/giFBA/package/gifba/gifba_object.py:333: RuntimeWarning: invalid value encountered in divide
#   is_overconsumed[env_tmp != 0] = -total_org_flux[np.abs(env_tmp) >= 1e-6].astype(np.longlong) / env_tmp[np.abs(env_tmp) >= 1e-6].astype(np.longlong) # only check non-zero env fluxes
# New convergence method update:
# Checking Convergence...
# Converged at iteration 2

# %%
media_flux_1_2
# Out:
# EX_lac_L(e)       5.565417
# EX_malthx(e)      0.000000
# EX_acald(e)       0.000000
# EX_cl(e)        999.997243
# EX_glyglu(e)      0.000000
#                    ...
# EX_gly(e)         0.000000
# EX_val_L(e)       0.000000
# EX_oxa(e)         0.000000
# EX_pro_L(e)       0.000000
# EX_met_L(e)     999.955739
# Name: 5, Length: 188, dtype: float64

# %%
org_flux = org_flux_1_2.groupby(level=["Model"]).sum()
org_flux["EX_biomass(e)"]
# Out:
# Model
# 0    0.095134
# 1    0.375533
# Name: EX_biomass(e), dtype: float64

# %%
community_1_2.summarize()
# Out:
# Community Summary (Cumulative through Iteration 4):
# Optimization Type: pfba
# Sum(Model_i Biomass) = 0.35467832297587293
#
# Uptake:
# Metabolite      Exchange      Flux  C-Number C-Flux
#   ala_L[e]   EX_ala_L(e)  0.197116         3  0.89%
#    hxan[e]    EX_hxan(e)  0.161281         5  1.21%
#     fe3[e]     EX_fe3(e)  0.002770         0  0.00%
#     mn2[e]     EX_mn2(e)  0.002770         0  0.00%
#  glycys[e]  EX_glycys(e)  0.046505         5  0.35%
#  pnto_R[e]  EX_pnto_R(e)  0.000935         9  0.01%
#     fe2[e]     EX_fe2(e)  0.002770         0  0.00%
#     nac[e]     EX_nac(e)  0.005539         6  0.05%
# cobalt2[e] EX_cobalt2(e)  0.002770         0  0.00%
#   glc_D[e]   EX_glc_D(e) 10.000000         6 89.85%
#   lys_L[e]   EX_lys_L(e)  0.098338         6  0.88%
#  ribflv[e]  EX_ribflv(e)  0.000935        17  0.02%
#   met_L[e]   EX_met_L(e)  0.046331         5  0.35%
#     ca2[e]     EX_ca2(e)  0.002770         0  0.00%
#   asn_L[e]   EX_asn_L(e)  0.083236         4  0.50%
#     nh4[e]     EX_nh4(e)  1.614069         0  0.00%
#     mg2[e]     EX_mg2(e)  0.002770         0  0.00%
#       k[e]       EX_k(e)  0.002770         0  0.00%
#      pi[e]      EX_pi(e)  0.511532         0  0.00%
#     so4[e]     EX_so4(e)  0.002770         0  0.00%
#     zn2[e]     EX_zn2(e)  0.002770         0  0.00%
#   ser_L[e]   EX_ser_L(e)  1.000000         3  4.49%
#     cu2[e]     EX_cu2(e)  0.002770         0  0.00%
#      cl[e]      EX_cl(e)  0.002770         0  0.00%
#   leu_L[e]   EX_leu_L(e)  0.155583         6  1.40%
#
# Secretion:
# Metabolite      Exchange      Flux  C-Number C-Flux
#      h2[e]      EX_h2(e) 16.602741         0  0.00%
#    etoh[e]    EX_etoh(e)  0.370223         2  1.41%
#       h[e]       EX_h(e)  2.936508         0  0.00%
#     h2o[e]     EX_h2o(e)  7.474929         0  0.00%
#     but[e]     EX_but(e)  8.396526         4 63.77%
#   his_L[e]   EX_his_L(e)  0.103897         6  1.18%
#     co2[e]     EX_co2(e) 17.715384         1 33.64%
# biomass[c] EX_biomass(e)  0.354678         0  0.00%
#
# -----------------------------------------------------------------
# Eubacterium hallii DSM 3353 (Model 1) Summary:
# 1.0 * biomass536 = 0.2948218000191044
#
# Eubacterium hallii DSM 3353 Uptake:
# Metabolite      Exchange         Flux  C-Number C-Flux
#   ala_L[e]   EX_ala_L(e) 1.971161e-01         3  0.94%
#    hxan[e]    EX_hxan(e) 1.348396e-01         5  1.07%
#     fe3[e]     EX_fe3(e) 2.302381e-03         0  0.00%
#     mn2[e]     EX_mn2(e) 2.302381e-03         0  0.00%
#  glycys[e]  EX_glycys(e) 3.083801e-02         5  0.25%
#     fe2[e]     EX_fe2(e) 2.302381e-03         0  0.00%
#     nac[e]     EX_nac(e) 4.604763e-03         6  0.04%
# cobalt2[e] EX_cobalt2(e) 2.302381e-03         0  0.00%
#       h[e]       EX_h(e) 6.284682e+00         0  0.00%
#   glc_D[e]   EX_glc_D(e) 5.000000e+00         6 47.67%
#   lys_L[e]   EX_lys_L(e) 9.833781e-02         6  0.94%
#   met_L[e]   EX_met_L(e) 4.633107e-02         5  0.37%
#     ca2[e]     EX_ca2(e) 2.302381e-03         0  0.00%
#   asn_L[e]   EX_asn_L(e) 6.918878e-02         4  0.44%
#     nh4[e]     EX_nh4(e) 1.163096e+00         0  0.00%
#   lac_L[e]   EX_lac_L(e) 8.868754e+00         3 42.28%
#     mg2[e]     EX_mg2(e) 2.302381e-03         0  0.00%
#       k[e]       EX_k(e) 2.302381e-03         0  0.00%
#      pi[e]      EX_pi(e) 4.229404e-01         0  0.00%
#     for[e]     EX_for(e) 6.664303e-09         1  0.00%
#     so4[e]     EX_so4(e) 2.302381e-03         0  0.00%
#     zn2[e]     EX_zn2(e) 2.302381e-03         0  0.00%
#   ser_L[e]   EX_ser_L(e) 1.000000e+00         3  4.77%
#     cu2[e]     EX_cu2(e) 2.302381e-03         0  0.00%
#      cl[e]      EX_cl(e) 2.302381e-03         0  0.00%
#   leu_L[e]   EX_leu_L(e) 1.293265e-01         6  1.23%
#
# Model 1 Secretion:
# Metabolite      Exchange         Flux  C-Number C-Flux
#      h2[e]      EX_h2(e) 1.660274e+01         0  0.00%
#     h2o[e]     EX_h2o(e) 6.039455e+00         0  0.00%
#      ac[e]      EX_ac(e) 4.341160e-08         2  0.00%
#     but[e]     EX_but(e) 8.396526e+00         4 65.29%
#   his_L[e]   EX_his_L(e) 1.094415e-01         6  1.28%
#     co2[e]     EX_co2(e) 1.719584e+01         1 33.43%
# biomass[c] EX_biomass(e) 2.948218e-01         0  0.00%
#
# -----------------------------------------------------------------
# Bifidobacterium longum infantis ATCC 15697 (Model 0) Summary:
# 1.0 * biomass525 = 0.05985652295676853
#
# Bifidobacterium longum infantis ATCC 15697 Uptake:
# Metabolite      Exchange     Flux  C-Number C-Flux
#    hxan[e]    EX_hxan(e) 0.026441         5  0.43%
#     fe3[e]     EX_fe3(e) 0.000467         0  0.00%
#     mn2[e]     EX_mn2(e) 0.000467         0  0.00%
#  glycys[e]  EX_glycys(e) 0.015667         5  0.26%
#  pnto_R[e]  EX_pnto_R(e) 0.000935         9  0.03%
#     fe2[e]     EX_fe2(e) 0.000467         0  0.00%
#     nac[e]     EX_nac(e) 0.000935         6  0.02%
# cobalt2[e] EX_cobalt2(e) 0.000467         0  0.00%
#   glc_D[e]   EX_glc_D(e) 5.000000         6 98.40%
#  ribflv[e]  EX_ribflv(e) 0.000935        17  0.05%
#   his_L[e]   EX_his_L(e) 0.005544         6  0.11%
#     ca2[e]     EX_ca2(e) 0.000467         0  0.00%
#   asn_L[e]   EX_asn_L(e) 0.014047         4  0.18%
#     nh4[e]     EX_nh4(e) 0.450972         0  0.00%
#     mg2[e]     EX_mg2(e) 0.000467         0  0.00%
#       k[e]       EX_k(e) 0.000467         0  0.00%
#      pi[e]      EX_pi(e) 0.088592         0  0.00%
#     so4[e]     EX_so4(e) 0.000467         0  0.00%
#     zn2[e]     EX_zn2(e) 0.000467         0  0.00%
#     cu2[e]     EX_cu2(e) 0.000467         0  0.00%
#      cl[e]      EX_cl(e) 0.000467         0  0.00%
#   leu_L[e]   EX_leu_L(e) 0.026257         6  0.52%
#
# Model 0 Secretion:
# Metabolite      Exchange     Flux  C-Number C-Flux
#    etoh[e]    EX_etoh(e) 0.370223         2  2.66%
#       h[e]       EX_h(e) 9.221190         0  0.00%
#     h2o[e]     EX_h2o(e) 1.435475         0  0.00%
#   lac_L[e]   EX_lac_L(e) 8.868754         3 95.48%
#     co2[e]     EX_co2(e) 0.519541         1  1.86%
# biomass[c] EX_biomass(e) 0.059857         0  0.00%
#
#
# Accessible at summary.flux or summary.env_flux for cumulative fluxes.

# %%
m2.metabolites.get_by_id('but[c]')
# Out:
# <Metabolite but[c] at 0x1794df680>

# %%
m2.reactions.get_by_id('BTCOAACCOAT')
# Out:
# <Reaction BTCOAACCOAT at 0x725e4e00f250>

# %%
org_flux_1_2.loc[(1,2),:]['BTCOAACCOAT']
# Out:
# -0.08981906558202592

# %%
media_flux_1_2.loc[1]['EX_but(e)']
# Out:
# 2.725766

# %% [markdown]
# Flux reversed? Flux not matching summary?

# %% [markdown]
# # Messing with Convergence tradeoff
# Slows time to convergence, but will increase the iteration interaction

# %%
import gifba
import cobra as cb

m1 = cb.io.load_matlab_model('AGORA2_Models/Bifidobacterium_longum_infantis_ATCC_15697.mat')
m2 = cb.io.load_matlab_model('AGORA2_Models/Eubacterium_hallii_DSM_3353.mat')

# AGORA Format
media = {
    'EX_o2(e)': 0, #aerobic/anaerobic
    'EX_h2o(e)': -1000,
    'EX_pi(e)': -1000,
    'EX_fe2(e)': -1000,
    'EX_fe3(e)': -1000,
    'EX_zn2(e)': -1000,
    'EX_so4(e)': -1000,
    'EX_cu2(e)': -1000,
    'EX_k(e)': -1000,
    'EX_mg2(e)': -1000,
    'EX_mn2(e)': -1000,
    'EX_cd2(e)': -1000,
    'EX_cl(e)': -1000,
    'EX_ca2(e)': -1000,
    'EX_cobalt2(e)': -1000,
    'EX_glc_D(e)': -10,
    'EX_nh4(e)': -20,

    'EX_ribflv(e)': -1000,
    'EX_pnto_R(e)': -1000,
    'EX_nac(e)': -1000,
    'EX_his_L(e)': -1000,
    'EX_asn_L(e)': -1000,
    'EX_glycys(e)': -1000,

    'EX_lys_L(e)': -1000,
    'EX_ala_L(e)': -1000,
    'EX_met_L(e)': -1000,
    'EX_leu_L(e)': -1000,
    'EX_hxan(e)': -1000,    
    'EX_ser_L(e)': -1,
}
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2684253
# Academic license - for non-commercial use only - expires 2026-07-02
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e

# %%
# initialize community
community_1 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5], step_size=1)
community_075 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5], step_size=0.75)
community_05 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5], step_size=0.5)
community_025 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5], step_size=0.25)
community_001 = gifba.gifbaObject([m1, m2], media, rel_abund=[0.5, 0.5], step_size=0.01)
# run iterations
its = 1000
media_flux_1, org_flux_1 = community_1.run_gifba(iters=its, method="pfba", early_stop=True, v=False)
media_flux_075, org_flux_075 = community_075.run_gifba(iters=its, method="pfba", early_stop=True, v=False)
media_flux_05, org_flux_05 = community_05.run_gifba(iters=its, method="pfba", early_stop=True, v=False)
media_flux_025, org_flux_025 = community_025.run_gifba(iters=its, method="pfba", early_stop=True, v=False)
media_flux_001, org_flux_001 = community_001.run_gifba(iters=its, method="pfba", early_stop=True, v=True)
# Out:
# Read LP format model from file /tmp/tmpochypwm8.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpyh6k3y52.lp
# Reading time = 0.01 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmpzpz1w3uj.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmp8wo8_prj.lp
# Reading time = 0.01 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmp7onujqum.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpfduoxqfu.lp
# Reading time = 0.01 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmp0179anj8.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmp_2oal8d_.lp
# Reading time = 0.01 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Read LP format model from file /tmp/tmpw8qit5r2.lp
# Reading time = 0.01 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpdrgwu4nc.lp
# Reading time = 0.01 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
# Iteration: 0
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 1
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 2
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 3
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 4
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 5
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 6
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 7
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 8
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 9
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 10
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 11
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 12
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 13
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 14
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 15
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 16
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 17
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 18
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 19
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 20
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 21
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 22
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 23
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 24
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 25
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 26
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 27
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 28
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 29
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 30
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 31
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 32
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 33
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 34
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 35
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 36
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 37
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 38
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 39
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 40
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 41
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 42
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 43
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 44
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 45
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 46
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 47
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 48
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 49
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 50
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 51
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 52
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 53
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 54
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 55
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 56
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 57
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 58
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 59
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 60
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 61
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 62
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 63
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 64
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 65
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 66
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 67
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 68
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 69
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 70
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 71
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 72
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 73
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 74
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 75
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 76
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 77
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 78
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 79
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 80
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 81
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 82
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 83
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 84
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 85
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 86
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 87
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 88
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 89
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 90
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 91
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 92
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 93
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 94
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 95
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 96
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 97
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 98
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 99
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 100
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 101
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 102
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 103
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 104
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 105
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 106
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 107
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 108
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 109
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 110
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 111
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 112
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 113
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 114
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 115
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 116
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 117
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 118
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 119
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 120
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 121
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 122
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 123
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 124
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 125
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 126
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 127
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 128
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 129
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 130
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 131
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 132
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 133
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 134
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 135
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 136
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 137
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 138
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 139
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 140
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 141
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 142
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 143
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 144
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 145
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 146
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 147
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 148
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 149
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 150
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 151
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 152
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 153
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 154
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 155
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 156
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 157
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 158
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 159
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 160
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 161
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 162
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 163
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 164
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 165
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 166
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 167
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 168
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 169
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 170
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 171
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 172
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 173
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 174
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 175
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 176
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 177
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 178
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 179
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 180
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 181
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 182
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 183
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 184
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 185
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 186
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 187
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 188
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 189
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 190
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 191
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 192
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 193
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 194
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 195
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 196
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 197
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 198
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 199
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 200
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 201
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 202
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 203
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 204
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 205
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 206
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 207
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 208
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 209
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 210
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 211
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 212
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 213
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 214
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 215
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 216
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 217
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 218
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 219
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 220
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 221
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 222
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 223
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 224
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 225
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 226
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 227
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 228
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 229
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 230
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 231
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 232
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 233
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 234
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 235
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 236
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 237
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 238
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 239
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 240
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 241
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 242
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 243
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 244
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 245
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 246
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 247
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 248
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 249
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 250
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 251
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 252
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 253
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 254
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 255
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 256
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 257
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 258
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 259
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 260
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 261
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 262
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 263
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 264
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 265
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 266
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 267
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 268
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 269
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 270
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 271
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 272
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 273
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 274
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 275
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 276
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 277
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 278
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 279
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 280
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 281
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 282
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 283
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 284
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 285
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 286
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 287
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 288
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 289
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 290
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 291
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 292
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 293
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 294
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 295
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 296
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 297
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 298
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 299
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 300
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 301
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 302
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 303
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 304
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 305
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 306
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 307
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 308
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 309
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 310
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 311
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 312
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 313
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 314
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 315
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 316
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 317
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 318
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 319
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 320
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 321
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 322
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 323
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 324
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 325
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 326
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 327
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 328
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 329
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 330
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 331
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 332
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 333
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 334
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 335
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 336
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 337
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 338
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 339
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 340
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 341
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 342
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 343
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 344
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 345
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 346
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 347
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 348
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 349
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 350
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 351
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 352
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 353
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 354
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 355
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 356
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 357
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 358
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 359
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 360
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 361
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 362
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 363
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 364
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 365
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 366
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 367
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 368
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 369
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 370
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 371
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 372
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 373
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 374
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 375
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 376
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 377
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 378
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 379
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 380
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 381
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Iteration: 382
#  Simulating model: 1  of  2
#  Simulating model: 2  of  2
# Checking Convergence...
# Converged at iteration 382

# %%
community_1.iter_converged, community_075.iter_converged, community_05.iter_converged, community_025.iter_converged, community_001.iter_converged
# Out:
# (2, 2, 6, 14, 382)

# %%
import matplotlib.pyplot as plt
import numpy as np
with community_001 as comm:
	plt.plot(comm.env_fluxes["EX_but(e)"], label='butyrate')
	plt.plot(comm.env_fluxes["EX_glc_D(e)"], label='glucose')
	plt.plot(comm.env_fluxes["EX_lac_L(e)"], label='lactate')
	plt.plot(comm.env_fluxes["EX_ac(e)"], label='acetate')
	plt.legend()

# %%
community_001.summarize()
# Out:
# Community Summary (Cumulative through Iteration 999):
# Optimization Type: pfba
# Sum(Model_i Biomass) = 0.35610934491021307
#
# Uptake:
# Metabolite      Exchange     Flux  C-Number C-Flux
#      pi[e]      EX_pi(e) 0.513568         0  0.00%
#      cl[e]      EX_cl(e) 0.002784         0  0.00%
#  glycys[e]  EX_glycys(e) 0.046598         5  0.35%
#       k[e]       EX_k(e) 0.002784         0  0.00%
#     cu2[e]     EX_cu2(e) 0.002784         0  0.00%
#     so4[e]     EX_so4(e) 0.002784         0  0.00%
#  ribflv[e]  EX_ribflv(e) 0.000929        17  0.02%
# cobalt2[e] EX_cobalt2(e) 0.002784         0  0.00%
#     nac[e]     EX_nac(e) 0.005564         6  0.05%
#   ala_L[e]   EX_ala_L(e) 0.198338         3  0.90%
#  pnto_R[e]  EX_pnto_R(e) 0.000929         9  0.01%
#   glc_D[e]   EX_glc_D(e) 9.957619         6 89.88%
#   ser_L[e]   EX_ser_L(e) 0.978490         3  4.42%
#   met_L[e]   EX_met_L(e) 0.046619         5  0.35%
#     mg2[e]     EX_mg2(e) 0.002784         0  0.00%
#    hxan[e]    EX_hxan(e) 0.161945         5  1.22%
#   lys_L[e]   EX_lys_L(e) 0.098947         6  0.89%
#     fe2[e]     EX_fe2(e) 0.002784         0  0.00%
#     ca2[e]     EX_ca2(e) 0.002784         0  0.00%
#     fe3[e]     EX_fe3(e) 0.002784         0  0.00%
#   asn_L[e]   EX_asn_L(e) 0.083572         4  0.50%
#     mn2[e]     EX_mn2(e) 0.002784         0  0.00%
#     zn2[e]     EX_zn2(e) 0.002784         0  0.00%
#     nh4[e]     EX_nh4(e) 1.645996         0  0.00%
#   leu_L[e]   EX_leu_L(e) 0.156210         6  1.41%
#
# Secretion:
# Metabolite      Exchange      Flux  C-Number C-Flux
#   lac_L[e]   EX_lac_L(e)  0.317638         3  1.82%
#      h2[e]      EX_h2(e) 16.725635         0  0.00%
#     for[e]     EX_for(e)  0.018099         1  0.03%
#     h2o[e]     EX_h2o(e)  7.261611         0  0.00%
#   his_L[e]   EX_his_L(e)  0.104610         6  1.20%
#       h[e]       EX_h(e)  2.843909         0  0.00%
#     but[e]     EX_but(e)  8.212507         4 62.80%
#      ac[e]      EX_ac(e)  0.014223         2  0.05%
#     co2[e]     EX_co2(e) 17.412228         1 33.29%
# biomass[c] EX_biomass(e)  0.356117         0  0.00%
#    etoh[e]    EX_etoh(e)  0.210434         2  0.80%
#
# -----------------------------------------------------------------
# Bifidobacterium longum infantis ATCC 15697 (Model 0) Summary:
# 1.0 * biomass525 = 0.05946023629455249
#
# Bifidobacterium longum infantis ATCC 15697 Uptake:
# Metabolite      Exchange     Flux  C-Number C-Flux
#      pi[e]      EX_pi(e) 0.088005         0  0.00%
#     for[e]     EX_for(e) 0.025686         1  0.09%
#      cl[e]      EX_cl(e) 0.000464         0  0.00%
#  glycys[e]  EX_glycys(e) 0.015564         5  0.26%
#   his_L[e]   EX_his_L(e) 0.005507         6  0.11%
#       k[e]       EX_k(e) 0.000464         0  0.00%
#     cu2[e]     EX_cu2(e) 0.000464         0  0.00%
#     so4[e]     EX_so4(e) 0.000464         0  0.00%
#  ribflv[e]  EX_ribflv(e) 0.000929        17  0.05%
# cobalt2[e] EX_cobalt2(e) 0.000464         0  0.00%
#     nac[e]     EX_nac(e) 0.000929         6  0.02%
#  pnto_R[e]  EX_pnto_R(e) 0.000929         9  0.03%
#      ac[e]      EX_ac(e) 0.239885         2  1.61%
#   glc_D[e]   EX_glc_D(e) 4.802693         6 96.68%
#     mg2[e]     EX_mg2(e) 0.000464         0  0.00%
#    hxan[e]    EX_hxan(e) 0.026266         5  0.44%
#     fe2[e]     EX_fe2(e) 0.000464         0  0.00%
#     ca2[e]     EX_ca2(e) 0.000464         0  0.00%
#     fe3[e]     EX_fe3(e) 0.000464         0  0.00%
#   asn_L[e]   EX_asn_L(e) 0.013954         4  0.19%
#     mn2[e]     EX_mn2(e) 0.000464         0  0.00%
#     zn2[e]     EX_zn2(e) 0.000464         0  0.00%
#     nh4[e]     EX_nh4(e) 0.447986         0  0.00%
#   leu_L[e]   EX_leu_L(e) 0.026083         6  0.53%
#
# Model 0 Secretion:
# Metabolite      Exchange     Flux  C-Number C-Flux
#   lac_L[e]   EX_lac_L(e) 8.803166         3 97.09%
#     h2o[e]     EX_h2o(e) 1.438814         0  0.00%
#       h[e]       EX_h(e) 8.887698         0  0.00%
#     co2[e]     EX_co2(e) 0.371611         1  1.37%
# biomass[c] EX_biomass(e) 0.059460         0  0.00%
#    etoh[e]    EX_etoh(e) 0.210439         2  1.55%
#
# -----------------------------------------------------------------
# Eubacterium hallii DSM 3353 (Model 1) Summary:
# 1.0 * biomass536 = 0.2966491086156606
#
# Eubacterium hallii DSM 3353 Uptake:
# Metabolite      Exchange     Flux  C-Number C-Flux
#   lac_L[e]   EX_lac_L(e) 8.485528         3 40.62%
#      pi[e]      EX_pi(e) 0.425562         0  0.00%
#      cl[e]      EX_cl(e) 0.002317         0  0.00%
#  glycys[e]  EX_glycys(e) 0.031029         5  0.25%
#       k[e]       EX_k(e) 0.002317         0  0.00%
#     cu2[e]     EX_cu2(e) 0.002317         0  0.00%
#     so4[e]     EX_so4(e) 0.002317         0  0.00%
#       h[e]       EX_h(e) 6.043786         0  0.00%
# cobalt2[e] EX_cobalt2(e) 0.002317         0  0.00%
#     nac[e]     EX_nac(e) 0.004633         6  0.04%
#   ala_L[e]   EX_ala_L(e) 0.198338         3  0.95%
#   glc_D[e]   EX_glc_D(e) 5.154925         6 49.36%
#   ser_L[e]   EX_ser_L(e) 0.978493         3  4.68%
#   met_L[e]   EX_met_L(e) 0.046618         5  0.37%
#     mg2[e]     EX_mg2(e) 0.002317         0  0.00%
#    hxan[e]    EX_hxan(e) 0.135675         5  1.08%
#   lys_L[e]   EX_lys_L(e) 0.098947         6  0.95%
#     fe2[e]     EX_fe2(e) 0.002317         0  0.00%
#     ca2[e]     EX_ca2(e) 0.002317         0  0.00%
#     fe3[e]     EX_fe3(e) 0.002317         0  0.00%
#   asn_L[e]   EX_asn_L(e) 0.069618         4  0.44%
#     mn2[e]     EX_mn2(e) 0.002317         0  0.00%
#     zn2[e]     EX_zn2(e) 0.002317         0  0.00%
#     nh4[e]     EX_nh4(e) 1.198010         0  0.00%
#   leu_L[e]   EX_leu_L(e) 0.130128         6  1.25%
#
# Model 1 Secretion:
# Metabolite      Exchange         Flux  C-Number C-Flux
#      h2[e]      EX_h2(e) 1.672564e+01         0  0.00%
#     for[e]     EX_for(e) 4.378331e-02         1  0.09%
#     h2o[e]     EX_h2o(e) 5.822786e+00         0  0.00%
#    succ[e]    EX_succ(e) 9.439671e-15         4  0.00%
#   his_L[e]   EX_his_L(e) 1.101198e-01         6  1.29%
#     but[e]     EX_but(e) 8.212503e+00         4 64.28%
#      ac[e]      EX_ac(e) 2.541011e-01         2  0.99%
#     co2[e]     EX_co2(e) 1.704061e+01         1 33.35%
# biomass[c] EX_biomass(e) 2.966491e-01         0  0.00%
#
#
# Accessible at summary.flux or summary.env_flux for cumulative fluxes.
